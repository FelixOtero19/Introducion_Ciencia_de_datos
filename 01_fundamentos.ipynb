# %% [markdown]
# <a href="https://colab.research.google.com/github/FelixOtero19/Introducion_Ciencia_de_datos/blob/main/01_fundamentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción a Python — Fundamentos
#
# **Introducción a la Ciencia de Datos (S100) · Maestría en Analítica de Datos, UTP**
#
# Este cuaderno es una guía práctica de los fundamentos de Python. Está pensado para que lo abras y trabajes **directamente sobre él**.
#
# ### ¿Cómo se usa?
# - El cuaderno se organiza en **celdas**: unas de texto (como esta) y otras de **código**.
# - Para ejecutar una celda de código, haz clic en ella y presiona **Shift + Enter**.
# - Puedes modificar el código y volver a ejecutarlo cuantas veces quieras. ¡Experimenta!
# - Busca las secciones **🔹 Tu turno**: son ejercicios para que completes tú.
#
# > **Recomendación:** ábrelo en **Google Colab** (Archivo → Abrir cuaderno → Subir) o en **Jupyter Notebook**. Guarda tu propia copia para conservar tu trabajo.
#
# ---

# %% [markdown]
# ## 1. Variables y tipos de datos
#
# Una **variable** guarda un valor y le da un nombre. En Python no hace falta declarar el tipo: se deduce del valor.
#
# Los tipos básicos son:
# - `str` — texto (cadenas)
# - `int` — números enteros
# - `float` — números decimales
# - `bool` — verdadero/falso (`True` / `False`)

# %%
# Creamos algunas variables
curso = "Ciencia de Datos"   # str  (texto)
creditos = 3                 # int  (entero)
promedio = 4.5               # float (decimal)
aprobado = True              # bool  (booleano)

# print() muestra un valor en pantalla
print(curso)
print(creditos)

# type() nos dice el tipo de un valor
print(type(curso))
print(type(promedio))
# Out:
# Ciencia de Datos
# 3
# <class 'str'>
# <class 'float'>

# %% [markdown]
# **🔹 Tu turno**
#
# Crea una variable `ciudad` con el nombre de tu ciudad, y otra `poblacion` con un número entero. Luego imprímelas.

# %%
# Escribe tu código aquí:
ciudad = "Panamá"
poblacion = 1353423244
print(f"{ciudad}, tipo: {type(ciudad)}")
print(f"{poblacion}, tipo: {type(poblacion)}")
# Out:
# Panamá, tipo: <class 'str'>
# 1353423244, tipo: <class 'int'>

# %% [markdown]
# ## 2. Operaciones básicas
#
# Python funciona como una calculadora. También compara valores.

# %%
a = 10
b = 3

print(a + b)   # suma
print(a - b)   # resta
print(a * b)   # multiplicación
print(a / b)   # división (da decimal)
print(a // b)  # división entera
print(a % b)   # residuo (módulo)
print(a ** b)  # potencia (a elevado a b)

# %%
# Comparaciones: devuelven True o False
print(a > b)    # ¿a es mayor que b?
print(a == b)   # ¿son iguales?  (ojo: == compara, = asigna)
print(a != b)   # ¿son diferentes?

# %% [markdown]
# **🔹 Tu turno**
#
# Si un producto cuesta 25 y compras 4, ¿cuánto pagas en total? Calcula y muestra el resultado.

# %%
# Escribe tu código aquí:
producto:int = 25
cantidad_solicitada: int= 4
total_por_pagar:int = producto*cantidad_solicitada
print(f"Total a pagar: {total_por_pagar}")
# Out:
# Total a pagar: 100

# %% [markdown]
# ## 3. Cadenas de texto (strings)
#
# Las cadenas se escriben entre comillas. Se pueden unir, medir y transformar.

# %%
nombre = "Ana"
apellido = "Pérez"

# Unir cadenas (concatenar)
completo = nombre + " " + apellido
print(completo)

# f-strings: insertar variables dentro del texto con f"..."
edad = 28
print(f"{nombre} tiene {edad} años.")

# Algunos métodos útiles
print(completo.upper())        # MAYÚSCULAS
print(completo.lower())        # minúsculas
print(len(completo))           # cantidad de caracteres
print(completo.replace("Ana", "Luisa"))
# Out:
# Ana Pérez
# Ana tiene 28 años.
# ANA PÉREZ
# ana pérez
# 9
# Luisa Pérez

# %% [markdown]
# **🔹 Tu turno**
#
# Crea una variable con tu nombre completo y muestra un mensaje como: *"Hola, me llamo ___ y mi nombre tiene ___ letras."* (usa una f-string y `len`).

# %%
# Escribe tu código aquí:
nombre_completo:str = "Félix Otero"
print(f"Hola, me llamo {nombre_completo} y mi nombre tiene {len(nombre_completo.replace(' ',''))} letras.")
# Out:
# Hola, me llamo Félix Otero y mi nombre tiene 10 letras.

# %% [markdown]
# ## 4. Listas
#
# Una **lista** guarda varios elementos en orden. Los índices empiezan en **0**.

# %%
temas = ["Python", "Estadística", "Machine Learning", "Visualización"]

print(temas)
print(temas[0])     # primer elemento
print(temas[1])     # segundo elemento
print(temas[-1])    # último elemento
print(len(temas))   # cantidad de elementos

# Rebanado (slicing): del índice 0 al 2 (el 2 no se incluye)
print(temas[0:2])

# Agregar un elemento al final
temas.append("Ética")
print(temas)
# Out:
# ['Python', 'Estadística', 'Machine Learning', 'Visualización']
# Python
# Estadística
# Visualización
# 4
# ['Python', 'Estadística']
# ['Python', 'Estadística', 'Machine Learning', 'Visualización', 'Ética']

# %%
# Recorrer una lista con un bucle for
for tema in temas:
    print("Tema:", tema)
# Out:
# Tema: Python
# Tema: Estadística
# Tema: Machine Learning
# Tema: Visualización
# Tema: Ética

# %% [markdown]
# **🔹 Tu turno**
#
# Crea una lista `intereses` con tres cosas que te interesen. Imprime el segundo elemento y la cantidad total de elementos.

# %%
# Escribe tu código aquí:
lista_intereses:list =["Peliculas","Futbol","Comida China"]
print(f"Imprimiendo el Segundo Elemento en lista: {lista_intereses[1]} - Cantidad total de elementos en lista: {len(lista_intereses)}")
# Out:
# Imprimiendo el Segundo Elemento en lista: Futbol - Cantidad total de elementos en lista: 3

# %% [markdown]
# ## 5. Diccionarios
#
# Un **diccionario** guarda pares `clave: valor`. Es ideal para describir "algo" con varias características.

# %%
estudiante = {
    "nombre": "Ana Pérez",
    "edad": 28,
    "grupo": 1,
    "aprobado": True
}

print(estudiante["nombre"])   # acceder por su clave
print(estudiante["edad"])

# Agregar o cambiar un valor
estudiante["correo"] = "ana.perez@utp.ac.pa"
print(estudiante)

# Ver todas las claves y valores
print(estudiante.keys())
print(estudiante.values())
# Out:
# Ana Pérez
# 28
# {'nombre': 'Ana Pérez', 'edad': 28, 'grupo': 1, 'aprobado': True, 'correo': 'ana.perez@utp.ac.pa'}
# dict_keys(['nombre', 'edad', 'grupo', 'aprobado', 'correo'])
# dict_values(['Ana Pérez', 28, 1, True, 'ana.perez@utp.ac.pa'])

# %% [markdown]
# **🔹 Tu turno**
#
# Crea un diccionario `libro` con las claves `titulo`, `autor` y `anio`. Luego imprime el autor.

# %%
# Escribe tu código aquí:
libro:dict ={
    "titulo":"Homo Deus",
    "autor":"Yuval Noah harari",
    "anio":"06/10/2016"
}

print(f"El Autor del Libro es: {libro['autor']}")
# Out:
# El Autor del Libro es: Yuval Noah harari

# %% [markdown]
# ## 6. Condicionales (if / elif / else)
#
# Permiten que el programa **tome decisiones**. Fíjate en los dos puntos `:` y en la **sangría** (indentación).

# %%
nota = 75

if nota >= 91:
    print("A")
elif nota >= 81:
    print("B")
elif nota >= 71:
    print("C")
else:
    print("Reprobado")
# Out:
# C

# %% [markdown]
# **🔹 Tu turno**
#
# Escribe un condicional que revise una variable `temperatura`: si es mayor a 30, imprime "Calor"; si es menor a 15, imprime "Frío"; en otro caso, "Templado".

# %%
temperatura = 22

# Escribe tu código aquí:
if temperatura > 30:
  print(f"Calor la temperatura es de:{temperatura}")
elif temperatura < 15:
  print(f"Frío la temperatura es de:{temperatura}")
else:
  print(f"Templado la temperatura es de:{temperatura}")
# Out:
# Templado la temperatura es de:22

# %% [markdown]
# ## 7. Bucles (for y while)
#
# Los bucles **repiten** acciones. `for` recorre una secuencia; `while` repite mientras se cumpla una condición.

# %%
# for con range: números del 1 al 5
for i in range(1, 6):
    print("Número:", i)
# Out:
# Número: 1
# Número: 2
# Número: 3
# Número: 4
# Número: 5

# %%
# while: repetir mientras la condición sea verdadera
contador = 0
while contador < 3:
    print("Vuelta", contador)
    contador = contador + 1
# Out:
# Vuelta 0
# Vuelta 1
# Vuelta 2

# %% [markdown]
# **🔹 Tu turno**
#
# Usa un bucle `for` para imprimir los cuadrados de los números del 1 al 5 (1, 4, 9, 16, 25).

# %%
# Escribe tu código aquí:
for i in range(1, 5):
    print(f"Numero:{i} al cuadrado es:{i**2}")
# Out:
# Numero:1 al cuadrado es:1
# Numero:2 al cuadrado es:4
# Numero:3 al cuadrado es:9
# Numero:4 al cuadrado es:16

# %% [markdown]
# ## 8. Funciones
#
# Una **función** agrupa código reutilizable. Se define con `def`, recibe **parámetros** y puede **devolver** (`return`) un resultado.

# %%
def saludar(nombre):
    return f"¡Hola, {nombre}!"

# Llamar (usar) la función
print(saludar("Ana"))
print(saludar("Carlos"))
# Out:
# ¡Hola, Ana!
# ¡Hola, Carlos!

# %%
def promedio(a, b, c):
    return (a + b + c) / 3

resultado = promedio(80, 90, 100)
print("El promedio es:", resultado)
# Out:
# El promedio es: 90.0

# %% [markdown]
# **🔹 Tu turno**
#
# Escribe una función `area_rectangulo(base, altura)` que devuelva el área (base × altura). Pruébala con base 5 y altura 3.

# %%
# Escribe tu código aquí:
def area_rectangulo(base, altura):
  return base*altura

print(area_rectangulo(5,3))
# Out:
# 15

# %% [markdown]
# ## 9. (Bonus) Un vistazo a los datos con pandas
#
# `pandas` es la librería que usaremos para trabajar con datos en forma de **tabla** (filas y columnas). Aquí solo un adelanto — lo veremos a fondo en la próxima clase.

# %%
import pandas as pd

# Creamos una tabla pequeña a partir de un diccionario
datos = {
    "nombre": ["Ana", "Luis", "María", "Carlos"],
    "edad":   [28, 34, 25, 41],
    "grupo":  [1, 2, 1, 2]
}

df = pd.DataFrame(datos)

# Ver la tabla
df
# Out:
#    nombre  edad  grupo
# 0     Ana    28      1
# 1    Luis    34      2
# 2   María    25      1
# 3  Carlos    41      2

# %%
# Primeras filas
print(df.head())

# Resumen estadístico de las columnas numéricas
print(df.describe())

# Filtrar: personas del grupo 1
print(df[df["grupo"] == 1])
# Out:
#    nombre  edad  grupo
# 0     Ana    28      1
# 1    Luis    34      2
# 2   María    25      1
# 3  Carlos    41      2
#             edad    grupo
# count   4.000000  4.00000
# mean   32.000000  1.50000
# std     7.071068  0.57735
# min    25.000000  1.00000
# 25%    27.250000  1.00000
# 50%    31.000000  1.50000
# 75%    35.750000  2.00000
# max    41.000000  2.00000
#   nombre  edad  grupo
# 0    Ana    28      1
# 2  María    25      1

# %% [markdown]
# ---
#
# ## ¿Y ahora qué?
#
# - Practicaste variables, tipos, operaciones, cadenas, listas, diccionarios, condicionales, bucles y funciones.
# - En la **Clase 2** profundizamos en las **estructuras de datos**, las **librerías fundamentales** (pandas y NumPy) y la **visualización con matplotlib**.
#
# **Tarea sugerida:** vuelve a hacer los ejercicios 🔹 sin ver los ejemplos, y guarda tu copia del cuaderno.
#
# *Si algo no corre, revisa la sangría y los dos puntos `:`; son los errores más comunes al empezar.*
